# %%
import boto3

# %%
glue_client = boto3.client('glue')

glue_client.create_database(
    DatabaseInput={
        'Name': 'state_of_data_db',
        'Description': 'Database do projeto State of Data - Tech Challenge Fase 3'
    }
)
# Out:
# {'ResponseMetadata': {'RequestId': 'a3e5becb-a42a-4d78-8f0a-9b7882408445',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Thu, 10 Sep 2026 21:36:28 GMT',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'a3e5becb-a42a-4d78-8f0a-9b7882408445',
#    'cache-control': 'no-cache'},
#   'RetryAttempts': 0}}

# %%
print("Database criado com sucesso.")
# Out:
# Database criado com sucesso.
